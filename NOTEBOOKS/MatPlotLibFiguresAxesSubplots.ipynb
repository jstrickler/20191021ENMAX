# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn
seaborn.set()

# %%
data = np.random.random(25)
data
data2 = np.random.random(25)
data2
# Out:
# array([0.04983229, 0.61841427, 0.81743506, 0.87048136, 0.77946512,
#        0.06393663, 0.43851859, 0.75068276, 0.72042841, 0.53584733,
#        0.47929404, 0.526715  , 0.27759211, 0.58076022, 0.98632334,
#        0.25244277, 0.80373883, 0.54863414, 0.80262126, 0.01852134,
#        0.46977937, 0.06483454, 0.13936767, 0.57284162, 0.26107154])

# %%
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.subplot(2, 3, 1)
plt.title("plt.subplot(2, 3, 1)")
plt.plot(data, 2 * data)
plt.subplot(2, 3, 2)
plt.plot(data, 3 * data)
plt.title("plt.subplot(2, 3, 2)")
plt.subplot(2, 3, 3)
plt.title("plt.subplot(2, 3, 3)")
plt.plot(data, 10 * data)
plt.subplot(2, 3, 4)
plt.title("plt.subplot(2, 3, 4)")
plt.pie(data[:8])
plt.subplot(2, 3, 5)
plt.title("plt.subplot(2, 3, 5)")
plt.bar(sorted(data[:5]), data2[:5], .1)
plt.subplot(2, 3, 6)
plt.title("plt.subplot(2, 3, 6)")
plt.scatter(data, data2)
