# %% [markdown]
# # Memory savings using categoricals

# %%
#!/usr/bin/env python
import pandas as pd

# %% [markdown]
# ## Without categoricals

# %%
# columns:
# Name,Position Title,Department,Employee Annual Salary
df_no_cat = pd.read_csv(
    "../DATA/city-of-chicago-salaries.csv",
    converters={'Employee Annual Salary':lambda s: float(s[1:])},
)
df_no_cat.head()
# Out:
#                     Name            Position Title        Department  \
# 0        AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1      AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC          AVIATION
#
#    Employee Annual Salary
# 0                 85512.0
# 1                 75372.0
# 2                 80916.0
# 3                 99648.0
# 4                 89440.0

# %%
df_no_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32054 entries, 0 to 32053
# Data columns (total 4 columns):
# Name                      32054 non-null object
# Position Title            32054 non-null object
# Department                32054 non-null object
# Employee Annual Salary    32054 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 1001.8+ KB

# %%
print(df_no_cat.describe(include="all"))
# Out:
#                        Name  Position Title Department  Employee Annual Salary
# count                 32054           32054      32054            32054.000000
# unique                31795            1098         35                     NaN
# top     RODRIGUEZ,  RICHARD  POLICE OFFICER     POLICE                     NaN
# freq                      4            9432      13623                     NaN
# mean                    NaN             NaN        NaN            75070.385710
# std                     NaN             NaN        NaN            23180.297928
# min                     NaN             NaN        NaN                0.960000
# 25%                     NaN             NaN        NaN            69576.000000
# 50%                     NaN             NaN        NaN            78012.000000
# 75%                     NaN             NaN        NaN            87303.000000
# max                     NaN             NaN        NaN           260004.000000

# %% [markdown]
# ## With categoricals

# %%
df_cat = pd.read_csv(
    "../DATA/city-of-chicago-salaries.csv",
    converters={'Employee Annual Salary':lambda s: float(s[1:])},
    dtype={"Position Title": "category", "Department": "category"},
)
df_cat
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2           AARON,  KIMBERLEI R
# 3           ABAD JR,  VICENTE M
# 4         ABBATACOLA,  ROBERT J
# 5         ABBATEMARCO,  JAMES J
# 6              ABBATE,  TERRY M
# 7              ABBOTT,  BETTY L
# 8             ABBOTT,  LYNISE M
# 9        ABBRUZZESE,  WILLIAM J
# 10              ABDALLAH,  ZAID
# 11        ABDELHADI,  ABDALMAHD
# 12          ABDELLATIF,  AREF R
# 13           ABDELMAJEID,  AZIZ
# 14           ABDELQAWI,  YOSEPH
# 15          ABDOLLAHZADEH,  ALI
# 16     ABDUL-KARIM,  MUHAMMAD A
# 17             ABDULLAH,  ASKIA
# 18          ABDULLAH,  DANIEL N
# 19             ABDULLAH,  KEVIN
# 20         ABDULLAH,  LAKENYA N
# 21          ABDULLAH,  RASHAD J
# 22            ABEJERO,  JASON V
# 23            ABELS,  KENNETH L
# 24        ABERCROMBIE,  TIMOTHY
# 25       ABOUELKHEIR,  HASSAN A
# 26           ABRAHAM,  GIRLEY T
# 27           ABRAHAM,  GODWIN K
# 28        ABRAMAVICIUS,  ANNA A
# 29          ABRAMS,  DANIELLE T
# ...                         ...
# 32024           ZUNIGA,  JUAN M
# 32025           ZUNIGA,  JURDON
 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32035                             SANITATION LABORER     STREETS & SAN
# 32036                                 POLICE OFFICER            POLICE
# 32037                            ELECTRICAL MECHANIC              OEMC
# 32038                           CONSTRUCTION LABORER       WATER MGMNT
# 32039              SENIOR PUBLIC INFORMATION OFFICER           FINANCE
# 32040                                LEGAL SECRETARY               LAW
# 32041                                 CROSSING GUARD            POLICE
# 32042                        POOL MOTOR TRUCK DRIVER        TRANSPORTN
# 32043                    AIRPORT OPERATIONS SUPVSR I          AVIATION
# 32044                                 POLICE OFFICER            POLICE
# 32045                                FIREFIGHTER-EMT              FIRE
# 32046                                 POLICE OFFICER            POLICE
# 32047                                 POLICE OFFICER            POLICE
# 32048                         MACHINIST (AUTOMOTIVE)  GENERAL SERVICES
# 32049                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32050                                 POLICE OFFICER            POLICE
# 32051                                 POLICE OFFICER            POLICE
# 32052                                 POLICE OFFICER            POLICE
# 32053                        CHIEF DATA BASE ANALYST              DoIT
#
#        Employee Annual Salary
# 0                     85512.0
# 1                     75372.0
# 2                     80916.0
# 3                     99648.0
# 4                     89440.0
# 5                     78012.0
# 6                     80724.0
# 7                      2756.0
# 8                     41784.0
# 9                     62832.0
# 10                    43104.0
# 11                    75372.0
# 12                    87792.0
# 13                    75372.0
# 14                    19167.2
# 15                    75372.0
# 16                    96384.0
# 17                    25008.0
# 18                    81906.0
# 19                   102978.0
# 20                    16286.4
# 21                    89440.0
# 22                    78012.0
# 23                    52008.0
# 24                    70408.0
# 25                    99648.0
# 26                    99648.0
# 27                    91980.0
# 28                    54432.0
# 29                    69576.0
# ...                       ...
# 32024                 78012.0
# 32025                 43104.0
# 32026                 43104.0
# 32027                 78012.0
# 32028                 40560.0
# 32029                 79140.0
# 32030                 46176.0
# 32031                 98394.0
# 32032                 75372.0
# 32033                 20560.8
# 32034                 96553.6
# 32035                 69576.0
# 32036                 83706.0
# 32037                 89440.0
# 32038                 76960.0
# 32039                 80916.0
# 32040                 66492.0
# 32041                 16286.4
# 32042                 70408.0
# 32043                 67128.0
# 32044                 78012.0
# 32045                 81906.0
# 32046                 80724.0
# 32047                 75372.0
# 32048                 91353.6
# 32049                 96553.6
# 32050                 78012.0
# 32051                 78012.0
# 32052                 80724.0
# 32053                110352.0
#
# [32054 rows x 4 columns]

# %%
print(df_cat.describe(include='all'))
# Out:
#                        Name  Position Title Department  Employee Annual Salary
# count                 32054           32054      32054            32054.000000
# unique                31795            1098         35                     NaN
# top     RODRIGUEZ,  RICHARD  POLICE OFFICER     POLICE                     NaN
# freq                      4            9432      13623                     NaN
# mean                    NaN             NaN        NaN            75070.385710
# std                     NaN             NaN        NaN            23180.297928
# min                     NaN             NaN        NaN                0.960000
# 25%                     NaN             NaN        NaN            69576.000000
# 50%                     NaN             NaN        NaN            78012.000000
# 75%                     NaN             NaN        NaN            87303.000000
# max                     NaN             NaN        NaN           260004.000000

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32054 entries, 0 to 32053
# Data columns (total 4 columns):
# Name                      32054 non-null object
# Position Title            32054 non-null category
# Department                32054 non-null category
# Employee Annual Salary    32054 non-null float64
# dtypes: category(2), float64(1), object(1)
# memory usage: 644.9+ KB

# %% [markdown]
# ## With categoricals (and splitting name)

# %%
df_cat_split = pd.read_csv(
    "../DATA/city-of-chicago-salaries.csv",    
    dtype={"Position Title": "category", "Department": "category"},
    converters={'Employee Annual Salary':lambda s: float(s[1:])},
)
df_cat_split['First Name'], df_cat_split['Last Name'] = df_cat_split.Name.str.split(',', 1).str
df_cat_split.drop('Name', axis=1, inplace=True)
df_cat_split['First Name'] = df_cat_split['First Name'].astype('category')
df_cat_split['Last Name'] = df_cat_split['Last Name'].astype('category')

df_cat_split.head()
# Out:
#              Position Title        Department  Employee Annual Salary  \
# 0          WATER RATE TAKER       WATER MGMNT                 85512.0
# 1            POLICE OFFICER            POLICE                 75372.0
# 2  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES                 80916.0
# 3         CIVIL ENGINEER IV       WATER MGMNT                 99648.0
# 4       ELECTRICAL MECHANIC          AVIATION                 89440.0
#
#    First Name      Last Name
# 0       AARON        ELVIA J
# 1       AARON      JEFFERY M
# 2       AARON    KIMBERLEI R
# 3     ABAD JR      VICENTE M
# 4  ABBATACOLA       ROBERT J

# %%
print(df_cat_split.describe(include="all"))
# Out:
#         Position Title Department  Employee Annual Salary First Name  \
# count            32054      32054            32054.000000      32054
# unique            1098         35                     NaN      13817
# top     POLICE OFFICER     POLICE                     NaN   WILLIAMS
# freq              9432      13623                     NaN        268
# mean               NaN        NaN            75070.385710        NaN
# std                NaN        NaN            23180.297928        NaN
# min                NaN        NaN                0.960000        NaN
# 25%                NaN        NaN            69576.000000        NaN
# 50%                NaN        NaN            78012.000000        NaN
# 75%                NaN        NaN            87303.000000        NaN
# max                NaN        NaN           260004.000000        NaN
#
#           Last Name
# count         32054
# unique        11644
# top       MICHAEL J
# freq            280
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# ## Results
# Let's look at memory usage for all 3 dataframes

# %%
df_no_cat.memory_usage(deep=True)
# Out:
# Index                          80
# Name                      2378643
# Position Title            2407193
# Department                2074713
# Employee Annual Salary     256432
# dtype: int64

# %%
print(df_cat.memory_usage(deep=True))
print()
# Out:
# Index                          80
# Name                      2378643
# Position Title             194406
# Department                  35727
# Employee Annual Salary     256432
# dtype: int64

# %%
print(df_cat_split.memory_usage(deep=True))
print()
# Out:
# Index                          80
# Position Title             194406
# Department                  35727
# Employee Annual Salary     256432
# First Name                1606450
# Last Name                 1167801
# dtype: int64

# %%
print(df["Department"].value_counts())
# Out:
# POLICE                   13623
# FIRE                      4731
# STREETS & SAN             2070
# WATER MGMNT               1857
# OEMC                      1292
# AVIATION                  1218
# TRANSPORTN                1168
# PUBLIC LIBRARY             926
# GENERAL SERVICES           913
# FAMILY & SUPPORT           727
# HEALTH                     573
# FINANCE                    520
# LAW                        450
# CITY COUNCIL               378
# BUILDINGS                  242
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           181
# BOARD OF ELECTION          110
# DoIT                        99
# MAYOR'S OFFICE              99
# CITY CLERK                  86
# IPRA                        85
# CULTURAL AFFAIRS            79
# PROCUREMENT                 71
# HUMAN RESOURCES             68
# ANIMAL CONTRL               61
# INSPECTOR GEN               50
# BUDGET & MGMT               44
# ADMIN HEARNG                42
# DISABILITIES                29
# TREASURER                   25
# HUMAN RELATIONS             18
# BOARD OF ETHICS              9
# POLICE BOARD                 2
# LICENSE APPL COMM            1
# Name: Department, dtype: int64
